# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('solarpowergeneration.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df=pd.read_csv('solarpowergeneration.csv')
#
# File c:\Users\godsc\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df
# Out:
#                            Timestamp Are you from Jaipur? What is your age?  \
# 0     2024/12/31 9:56:27 am GMT+5:30                  Yes             20-29
# 1    2024/12/31 12:35:40 pm GMT+5:30                  Yes      19 and below
# 2    2024/12/31 12:54:10 pm GMT+5:30                  Yes      19 and below
# 3     2024/12/31 2:49:46 pm GMT+5:30                  Yes      19 and below
# 4     2024/12/31 2:57:22 pm GMT+5:30                  Yes      19 and below
# ..                               ...                  ...               ...
# 919  2025/01/20 11:58:51 am GMT+5:30                  Yes      19 and below
# 920  2025/01/20 11:59:10 am GMT+5:30                  Yes             20-29
# 921  2025/01/20 12:07:40 pm GMT+5:30                  Yes             20-29
# 922  2025/01/20 12:07:49 pm GMT+5:30                   No             20-29
# 923  2025/01/20 12:09:21 pm GMT+5:30                  Yes             20-29
#
# ...

# %%
df.head()
# Out:
#                          Timestamp Are you from Jaipur? What is your age?  \
# 0   2024/12/31 9:56:27 am GMT+5:30                  Yes             20-29
# 1  2024/12/31 12:35:40 pm GMT+5:30                  Yes      19 and below
# 2  2024/12/31 12:54:10 pm GMT+5:30                  Yes      19 and below
# 3   2024/12/31 2:49:46 pm GMT+5:30                  Yes      19 and below
# 4   2024/12/31 2:57:22 pm GMT+5:30                  Yes      19 and below
#
#   What is your gender?     What is your departure address (with pincode)?  \
# 0                 Male  2/627, Sector 2, Malviya Nagar, Jaipur, Rajast...
# 1               Female  Flat no 201 Vatsalya Enclave Ganesh Nagar Iskc...
# 2                 Male  Swastik Villas, New Sanganer Road, Jaipur(302020)
# 3                 Male                                             305001
# 4                 Male                            24/25 sagar apartments
#
#    What is your destination address?  (with pincode)  \
# ...

# %%
df.tail()
# Out:
#                            Timestamp Are you from Jaipur? What is your age?  \
# 919  2025/01/20 11:58:51 am GMT+5:30                  Yes      19 and below
# 920  2025/01/20 11:59:10 am GMT+5:30                  Yes             20-29
# 921  2025/01/20 12:07:40 pm GMT+5:30                  Yes             20-29
# 922  2025/01/20 12:07:49 pm GMT+5:30                   No             20-29
# 923  2025/01/20 12:09:21 pm GMT+5:30                  Yes             20-29
#
#     What is your gender?     What is your departure address (with pincode)?  \
# 919                 Male                                Mansarovar (302020)
# 920                 Male  Dlb Rise apartment , Ganesh nagar , Mansarovar...
# 921               Female                                  Mansarover 302020
# 922                 Male                                  Mansarovar 302020
# 923               Female                                             302016
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 924 entries, 0 to 923
# Data columns (total 29 columns):
#  #   Column                                                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                                                             --------------  -----
#  0   Timestamp                                                                                                                                          924 non-null    object
#  1   Are you from Jaipur?                                                                                                                               919 non-null    object
#  2   What is your age?                                                                                                                                  922 non-null    object
# ...

# %%
df.describe()
# Out:
#                               Timestamp Are you from Jaipur?  \
# count                               924                  919
# unique                              905                    2
# top     2025/01/16 12:24:29 pm GMT+5:30                  Yes
# freq                                  2                  705
#
#        What is your age? What is your gender?  \
# count                922                  919
# unique                 6                    2
# top                20-29                 Male
# freq                 531                  622
#
#        What is your departure address (with pincode)?  \
# count                                             871
# unique                                            668
# top                                            302017
# freq                                               81
#
#        What is your destination address?  (with pincode)  \
# count                                                844
# ...

# %%
df.isnull()
# Out:
#      Timestamp  Are you from Jaipur?  What is your age?  What is your gender?  \
# 0        False                 False              False                 False
# 1        False                 False              False                 False
# 2        False                 False              False                 False
# 3        False                 False              False                 False
# 4        False                 False              False                 False
# ..         ...                   ...                ...                   ...
# 919      False                 False              False                 False
# 920      False                 False              False                 False
# 921      False                 False              False                 False
# 922      False                 False              False                 False
# 923      False                 False              False                 False
#
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                                              0
# Are you from Jaipur?                                                                                                                                   5
# What is your age?                                                                                                                                      2
# What is your gender?                                                                                                                                   5
# What is your departure address (with pincode)?                                                                                                        53
# What is your destination address?  (with pincode)                                                                                                     80
# ...

# %%
df['Are you from Jaipur?'].value_counts()
# Out:
# Are you from Jaipur?
# Yes    705
# No     214
# Name: count, dtype: int64

# %%
df['What is your age?'].value_counts()
# Out:
# What is your age?
# 20-29           531
# 19 and below    342
# 40-49            20
# 30-39            20
# 50-59             7
# 80 and above      2
# Name: count, dtype: int64

# %%
df['What is your gender?'].value_counts()
# Out:
# What is your gender?
# Male      622
# Female    297
# Name: count, dtype: int64

# %%
df['What is your departure address (with pincode)?'].value_counts()
# Out:
# What is your departure address (with pincode)?
# 302017                                    81
# Jagatpura 302017                          16
# 302012                                    12
# 302020                                     9
# 302004                                     6
#                                           ..
# 335513                                     1
# Vasant Kunj block B south delhi 110070     1
# Shiv nagar 2nd (302039)                    1
# Manbagh , jaisinghpura Khor - 302027       1
# Mansarover 302020                          1
# Name: count, Length: 668, dtype: int64

# %%
df['What is your destination address? (with pincode)'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'What is your destination address? (with pincode)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ...

# %%
df['What is your mode of transportation?'].value_counts()
# Out:
# What is your mode of transportation?
# Two Wheeler                        324
# Public Transport                   216
# Walk                               152
# Car                                 98
# Cabs Services                       95
# College bus                          6
# College Bus                          5
# College bus                          2
# Walking                              1
# Institution provided transport       1
# Udke                                 1
# Uber                                 1
# Bus                                  1
# Magic                                1
# University Bus                       1
# Auto                                 1
# Train                                1
# college bus                          1
# University Bus                       1
# College Bus                          1
# Railway                              1
# Cycle                                1
# A water pot made of brass            1
# ...

# %%
df['If Public Transport, Do you get seat availability easily?'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'If Public Transport, Do you get seat availability easily?'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ...

# %%
df['If personal vehicles do you find a parking space easily?'].value_counts()
# Out:
# If personal vehicles do you find a parking space easily?
# No     445
# Yes    413
# Name: count, dtype: int64

# %%
df['How long do you wait for Public Transport?'].value_counts()
# Out:
# How long do you wait for Public Transport?
# 0-30 Minutes             609
# 31-60 Minutes            157
# More than 120 Minutes     28
# 61-90 Minutes             21
# 91-120 Minutes             5
# Name: count, dtype: int64

# %%
df[''].value_counts()

# %%
df[''].value_counts()

# %%
df[''].value_counts()

# %%
# Here we will check the percentage of nan values present in each feature
## STEP-1:make the list of fetaures which has missing values
features_with_na=[features for features in df.columns if df[features].isnull().sum()>1]

# %%
## STEP-2:print the feature name and the percentage of missing values
for feature in features_with_na:
    print(feature,np.round(df[feature].isnull().mean(),4),'% missing values')
# Out:
# Are you from Jaipur? 0.0054 % missing values
# What is your age? 0.0022 % missing values
# What is your gender? 0.0054 % missing values
# What is your departure address (with pincode)? 0.0574 % missing values
# What is your destination address?  (with pincode) 0.0866 % missing values
# What is your mode of transportation? 0.0119 % missing values
# If Public Transport, Do you get seat availability easily?   0.0996 % missing values
# If personal vehicles do you find a parking space easily? 0.0714 % missing values
# How long do you wait for Public Transport? 0.1126 % missing values
# What time do you prefer to leave your house to work/school/university/hospital? 0.013 % missing values
# How much time (minutes) do you take to travel ? 0.0292 % missing values
# What time do you prefer to leave your work/school/university/ hospital for home? 0.026 % missing values
# How long time (minutes) do you travel? 0.0444 % missing values
# ...
